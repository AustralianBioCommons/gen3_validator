# %%
import gen3_validator

import logging
logging.basicConfig(level=logging.DEBUG)


schema_path = "/Users/harrijh/projects/gen3_validator/tests/schema/gen3_test_schema.json"

resolver = gen3_validator.ResolveSchema(schema_path)
resolver.resolve_schema()
schema = resolver.schema_resolved
from jsonschema import Draft4Validator
# data = [
#         {
#             "submitter_id": "lipidomics-assay-ausdiab-12-221-990940238_e91aef83bc5a85c37d2c8ddbb289de3ffc863bbb3489c650b3a10f13f1477895",
#             "type": "lipidomics_assay",
#             "assay_id": "AD12_250#12-221-990940238",
#             "assay_description": "Targeted mass spec lipidome",
#             "instrument_type": "Agilent QQQ LC-MS",
#             "samples": [
#                 {
#                     "submitter_id": "sample-ausdiab-0441301_e91aef83bc5a85c37d2c8ddbb289de3ffc863bbb3489c650b3a10f13f1477895"
#                 }
#             ]
#         }
# ]



data = [
    {
        "atrial_fibrillation": "yes",
        "cabg": "yes",
        "type": "medical_history"
    }
]
# import json 
# with open("/Users/harrijh/projects/gen3_validator/tests/data/pass/sample.json", "r") as f: 
#     data = json.load(f)

# schema = schema.get("lipidomics_assay.yaml")
# validator = Draft4Validator(schema)
# errors = list(validator.iter_errors(data[0]))


gen3_validator.validate.validate_list_dict(data, schema)
# Out:
# INFO:gen3_validator.dict:Initializing DataDictionary with schema path: /Users/harrijh/projects/gen3_validator/tests/schema/gen3_test_schema.json
# INFO:gen3_validator.resolve_schema:Initializing ResolveSchema with schema path: /Users/harrijh/projects/gen3_validator/tests/schema/gen3_test_schema.json
# INFO:gen3_validator.resolve_schema:Starting schema resolution process.
# INFO:gen3_validator.dict:Reading JSON file from path: /Users/harrijh/projects/gen3_validator/tests/schema/gen3_test_schema.json
# INFO:gen3_validator.dict:Successfully read JSON schema.
# INFO:gen3_validator.dict:Retrieving node names from schema.
# INFO:gen3_validator.dict:Splitting schema into individual node schemas.
# INFO:gen3_validator.dict:Split schema into individual node schemas.
# INFO:gen3_validator.dict:Retrieving schema for schema ID: _definitions.yaml
# INFO:gen3_validator.resolve_schema:Retrieved definitions schema.
# INFO:gen3_validator.dict:Retrieving schema for schema ID: _terms.yaml
# INFO:gen3_validator.resolve_schema:Retrieved terms schema.
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved references in definitions schema.
# INFO:gen3_validator.resolve_schema:Resolving all references in schema list.
# INFO:gen3_validator.resolve_schema:=== Resolving Schema References ===
# INFO:gen3_validator.dict:Retrieving node names from schema.
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved demographic.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved clinical_descriptor.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved project.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved serum_marker_assay.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved imaging_file.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved lipidomics_assay.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved metabolomics_file.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved acknowledgement.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved medical_history.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved _settings.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved blood_pressure_test.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved genomics_assay.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved qc_file.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved program.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved serum_marker_file.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved proteomics_assay.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved sample.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved supplementary_file.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved genomics_file.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved proteomics_file.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved exposure.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved metabolomics_assay.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved lipidomics_file.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved lab_result.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved medication.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved publication.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved subject.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved analysis_workflow.yaml
# INFO:gen3_validator.resolve_schema:Resolving references in schema.
# INFO:gen3_validator.resolve_schema:Resolved core_metadata_collection.yaml
# INFO:gen3_validator.resolve_schema:Resolved all references in schema list.
# INFO:gen3_validator.dict:Converting schema list to JSON format.
# INFO:gen3_validator.resolve_schema:Converted resolved schema list to JSON format.
# DEBUG:gen3_validator.validate:Object at index 0 validated with 1 errors.
# DEBUG:gen3_validator.validate:Validating object at index 0 of type 'medical_history'.
# DEBUG:gen3_validator.validate:Found 1 validation error(s) for object at index 0 (type: 'medical_history').
# DEBUG:gen3_validator.validate:Validation error in object at index 0, node 'medical_history': invalid_key='root', schema_path='required', validator='required', validator_value='['submitter_id', 'type']', error=''submitter_id' is a required property'
# [{'node': 'medical_history',
#   'index': 0,
#   'validation_result': 'FAIL',
#   'invalid_key': 'root',
#   'schema_path': 'required',
#   'validator': 'required',
#   'validator_value': ['submitter_id', 'type'],
#   'validation_error': "'submitter_id' is a required property"}]

# %%
for error in errors:
    print("Message:", error.message)
    print("Path:", list(error.path))
    print("Schema path:", list(error.schema_path))
    print("Instance:", error.instance)
    print("Validator:", error.validator)
    print("-" * 40)
# Out:
# Message: 'Agilent QQQ LC-MS' is not one of ['LC-MS', 'MS/MS', 'Multidimensional MS', 'Ion Mobility MS', 'MALDI MS', 'GC-MS', 'High Mass Accuracy MS']
# Path: ['instrument_type']
# Schema path: ['properties', 'instrument_type', 'enum']
# Instance: Agilent QQQ LC-MS
# Validator: enum
# ----------------------------------------
